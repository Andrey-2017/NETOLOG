# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cols = ['Name', 'Gender', 'Count']
year = '1950'
names_all = pd.read_csv('D:\PITON\DATA\yob{0}.txt'.format(year), names=cols)
need_names = (names_all[names_all['Name'].str.contains('R')].groupby('Name').sum()
    .sort_values(by='Count', ascending=False)).head(10).plot.pie(y='Count')
