# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
names_year = {}
cols = ['Name', 'Gender', 'Count']
for year in range(1900, 2000, 5):
    names_year[year] = pd.read_csv('D:\PITON\DATA\yob{0}.txt'.format(year), names=cols)
names_all = pd.concat(names_year, names=['Year', 'Pos'])
need_names = (names_all.groupby([names_all.index.get_level_values(0), 'Name']).sum().query('Name == ["Ruth", "Robert"]')
    .unstack('Name')).plot.bar()
